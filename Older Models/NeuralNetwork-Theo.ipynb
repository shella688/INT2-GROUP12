# %%
#imports
import math
#PyTorch imports
import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

#Import SciPy to load the Flowers-102 dataset from the .mat format
import scipy.io

#Other imports
import numpy as np
import matplotlib.pyplot as plt

#Import time so that we can train the model within the 12 hour time limit
import time

# %%
#Define transforms
trainingTransform = transforms.Compose([
    transforms.Resize(224), #Change this value to edit the image size
    transforms.RandomRotation(90), #Rotates each image by a random angle between 0-90 degrees
    transforms.CenterCrop(224), #Must be the same as resize value. This is used to ensure the image is square
    #Default probability for both flips is p=0.5, can be changed if needed
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(0,1) #zerocenter normalization
])

nonTrainTransform = transforms.Compose([
    #Same as training transform without flipping as required
    #by assessment rules
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(0,1)
])

#Load Flowers-102 dataset and split it into train, validate and test splits
trainingSet = datasets.Flowers102(root="./flowers", split="train", download=True, transform=trainingTransform)
validationSet = datasets.Flowers102(root="./flowers", split="val", download=True, transform=nonTrainTransform)
testingSet = datasets.Flowers102(root="./flowers", split="test", download=True, transform=nonTrainTransform)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to flowers/flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:24<00:00, 13803072.78it/s]
# Extracting flowers/flowers-102/102flowers.tgz to flowers/flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to flowers/flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 230921.32it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to flowers/flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 15248222.81it/s]

# %%
#Checking the splits are the correct length
print(len(trainingSet))
print(len(validationSet))
print(len(testingSet))
# Out:
# 1020
# 1020
# 6149

# %%
#Checking the training transformations are ok
figure = plt.figure(figsize=(10,10))
col, row = 2, 2
for i in range(1, 5): #TODO: Change this to be rows * columns
  randImg = torch.randint(len(trainingSet), size=(1,)).item() #Size defines the shape of the tensor
  img, label = trainingSet[randImg]
  figure.add_subplot(row, col, i)
  plt.title(label)
  plt.axis(False)
  plt.imshow(img.squeeze().permute(1,2,0)) #Permute gets the dimentions in the correct order
plt.show()

# %%
#Checking if collab can connect to a GPU
if torch.cuda.is_available():
  device = torch.device('cuda:0')
else:
  device = torch.device('cpu')

# %%
#The CNN itself
class CNN(nn.Module):
  def __init__(self):
    super().__init__()
    #DEFINING THE LAYERS. THIS IS WHERE WE WILL SPEND MOST OF OUR TIME
    self.netLayers = nn.Sequential(
        # block 1 (<- considering how to talk abt layers in method don't mind me)
        nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.MaxPool2d(2,2),

        #block 2
        nn.ReLU(),
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        
        #block 3
        nn.AvgPool2d(2,2),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(256),

        #nn.LeakyReLU(), #LeakyReLU is used to prevent 'dead ReLU' issues
        
        #block 4
        nn.ReLU(),
        nn.MaxPool2d(2,2),
        nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=(1,1), padding=1),
        
        # block 5
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.MaxPool2d(2,2),
        nn.Flatten(),
        #IMPORTANT: in channels for first linear must be
        # (image size) * (image size) * C
        #Where C is the out channels of the last conv2d
        #If confused, just print out the shape of the matrix

        # fully connected layer
        nn.Linear(100352, 1020),
        nn.BatchNorm1d(1020),
        nn.ReLU(),
        nn.Dropout(0.5),

        nn.Linear(1020, 1020),
        nn.BatchNorm1d(1020),
        nn.LeakyReLU(),
        nn.Dropout(0.5),

        nn.Linear(1020, 256),
        
        #nn.LogSoftmax(dim=1)
    )

    self.two = nn.Sequential(
        nn.Flatten(),
        nn.LazyLinear(1020),
        nn.BatchNorm1d(1020),
        nn.ReLU(),
        nn.Dropout(0.5),

        nn.Linear(1020, 1020),
        nn.BatchNorm1d(1020),
        nn.LeakyReLU(),
        nn.Dropout(0.5),
        nn.Linear(1020, 512),
        nn.BatchNorm1d(512),
        nn.LeakyReLU(),
        nn.Dropout(0.5),
    )

    self.join = nn.Bilinear(512, 256, 512)
    self.three = nn.Sequential(
        nn.BatchNorm1d(512),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.LazyLinear(256),
        nn.LazyLinear(256),
        nn.Linear(256, 102), #102 for the classifiers
    )
  
  def forward(self, x):
      result = self.netLayers(x)
      result2 = self.two(x)
      result = self.join(result2, result)
      result = self.three(result)
      #print(result.shape)
      return result
  

print(CNN())
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# CNN(
#   (netLayers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU()
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Flatten(start_dim=1, end_dim=-1)
#     (24): Linear(in_features=100352, out_features=1020, bias=True)
#     (25): BatchNorm1d(1020, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#     (27): Dropout(p=0.5, inplace=False)
#     (28): Linear(in_features=1020, out_features=1020, bias=True)
#     (29): BatchNorm1d(1020, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (30): LeakyReLU(negative_slope=0.01)
#     (31): Dropout(p=0.5, inplace=False)
#     (32): Linear(in_features=1020, out_features=256, bias=True)
#   )
#   (two): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): LazyLinear(in_features=0, out_features=1020, bias=True)
#     (2): BatchNorm1d(1020, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Linear(in_features=1020, out_features=1020, bias=True)
#     (6): BatchNorm1d(1020, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=1020, out_features=512, bias=True)
#     (10): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Dropout(p=0.5, inplace=False)
#   )
#   (join): Bilinear(in1_features=512, in2_features=256, out_features=512, bias=True)
#   (three): Sequential(
#     (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): LazyLinear(in_features=0, out_features=256, bias=True)
#     (4): LazyLinear(in_features=0, out_features=256, bias=True)
#     (5): Linear(in_features=256, out_features=102, bias=True)
#   )
# )

# %%
#TODO: Code to train the CNN on the training set for a set amount of minutes.
def timedTrain(minutes, cnn, lossFunction, optimiser, showGraph):
  startTime = time.time()
  endTime = time.time() + (minutes * 60)
  trainingError = []

# %%
#Code to train the CNN based on a set number of epochs
def epochCountTrain(trainLoader, cnn, optimizer, lossFunction):
  totalLoss, correct = 0, 0
  size = len(trainLoader.dataset)
  for i, data in enumerate(trainLoader, 0):
    input, labels = data
    input = input.to(device)
    labels = labels.to(device)
    optimizer.zero_grad()
    output = cnn(input)
    loss = lossFunction(output, labels)
    loss.backward()
    optimizer.step()
    totalLoss += loss.item()
    correct += (output.argmax(1)==labels).sum().item()
    if i % 20 == 0:
      loss, currentLoss = loss.item(), (i + 1) * len(input)
      print(f"loss: {loss:>7f}    [{currentLoss:>5d}/{size:>5d}]")
      
  epochTrainLoss.append(float(loss))
  epochTrainAccuracy.append(round((correct/1020)*100, 1))
  print(f"\nAvg train loss: {(totalLoss/len(trainLoader)):>8f}")
  print(f"Train accuracy = {((correct/1020) * 100): >0.1f}%")

# %%
#Code to guess accuracy based on validation set
def validation(valLoader, cnn, lossFunction):
  valSize = len(valLoader.dataset)
  correct = 0
  loss = []
  with torch.no_grad(): #as we are not calling backward, use no grad to save memory
    for batch in valLoader:
      input, labels = batch
      input = input.to(device)
      labels = labels.to(device)
      prediciton = cnn(input)
      loss.append(lossFunction(prediciton, labels).item())
      correct += (prediciton.argmax(1) == labels).sum().item()
  
  epochValLoss.append((np.average(loss)))
  epochValAccuracy.append(round((correct/valSize)*100, 1))
  print(f"Accuracy on validation set = {((correct / valSize) * 100):>0.1f}%")
  print(f"Average loss on validation set = {(np.average(loss))}\n")

# %%
#Code that gets the accuracy of the test set!
def test(testLoader, cnn):
  testSize = len(testLoader.dataset)
  correct = 0
  with torch.no_grad():
    for batch in testLoader:
      input, labels = batch
      input = input.to(device)
      labels = labels.to(device)
      prediciton = cnn(input)
      correct +=(prediciton.argmax(1) == labels).sum().item()
  print("----------------------------------------------------")    
  print(f"Accuracy on test set = {((correct / testSize) * 100):>0.1f}%")
  print("----------------------------------------------------")

# %%
model = CNN().to(device)
epochTrainLoss = []
epochTrainAccuracy = []

epochValLoss = []
epochValAccuracy = []

epochCountList = []

# %%
#Instantiate the model, loss function and optimiser, done to prevent resets when rerunning the code below
epochCount = 50
learningRate = 0.00001
batchSize = 32
lossFunction = nn.CrossEntropyLoss()

optimizer = AdamW(lr=learningRate, params=model.parameters(), weight_decay=0.1)
trainDataloader = DataLoader(trainingSet, batch_size=batchSize, shuffle=True)
valDataloader = DataLoader(validationSet, batch_size=batchSize, shuffle=True)
testDataloader = DataLoader(validationSet, batch_size=batchSize, shuffle=True)

# %%
#Actual code to get it all running
scheduler = StepLR(optimizer, step_size=30, gamma=0.3)
for i in range(epochCount):
  print(f"Epoch {i+1}")
  model.train()
  epochCountTrain(trainDataloader, model, optimizer, lossFunction)
  scheduler.step()
  model.eval()
  validation(valDataloader, model, lossFunction)
  epochCountList.append(i+1)
# Out:
# Epoch 1
# loss: 2.084389    [   32/ 1020]
# loss: 2.095796    [  672/ 1020]
#
# Avg train loss: 2.226348
# Train accuracy = 41.3%
# Accuracy on validation set = 31.3%
# Average loss on validation set = 2.827233672142029
#
# Epoch 2
# loss: 2.212009    [   32/ 1020]
# loss: 1.930968    [  672/ 1020]
#
# Avg train loss: 2.192268
# Train accuracy = 43.0%
# Accuracy on validation set = 30.4%
# Average loss on validation set = 2.8084035739302635
#
# Epoch 3
# loss: 2.240114    [   32/ 1020]
# loss: 2.253171    [  672/ 1020]
#
# Avg train loss: 2.155045
# Train accuracy = 46.0%
# Accuracy on validation set = 29.8%
# Average loss on validation set = 2.8188977390527725
#
# Epoch 4
# loss: 2.176582    [   32/ 1020]
# loss: 2.029755    [  672/ 1020]
#
# Avg train loss: 2.140270
# Train accuracy = 45.1%
# Accuracy on validation set = 30.4%
# Average loss on validation set = 2.8245445638895035
#
# Epoch 5
# loss: 2.182824    [   32/ 1020]
# loss: 2.328323    [  672/ 1020]
#
# Avg train loss: 2.159151
# Train accuracy = 45.0%
# Accuracy on validation set = 30.8%
# Average loss on validation set = 2.788534827530384
#
# Epoch 6
# loss: 2.040859    [   32/ 1020]
# loss: 2.254544    [  672/ 1020]
#
# Avg train loss: 2.121060
# Train accuracy = 46.2%
# Accuracy on validation set = 32.0%
# Average loss on validation set = 2.7912794947624207
#
# Epoch 7
# loss: 1.956654    [   32/ 1020]
# loss: 2.089227    [  672/ 1020]
#
# Avg train loss: 2.109513
# Train accuracy = 47.9%
# Accuracy on validation set = 31.1%
# Average loss on validation set = 2.8001196160912514
#
# Epoch 8
# loss: 2.140544    [   32/ 1020]
# loss: 2.073689    [  672/ 1020]
#
# Avg train loss: 2.058914
# Train accuracy = 47.7%
# Accuracy on validation set = 30.9%
# Average loss on validation set = 2.8014282435178757
#
# Epoch 9
# loss: 2.053984    [   32/ 1020]
# loss: 1.820476    [  672/ 1020]
#
# Avg train loss: 2.139324
# Train accuracy = 45.8%
# Accuracy on validation set = 32.0%
# Average loss on validation set = 2.7734917029738426
#
# Epoch 10
# loss: 2.030458    [   32/ 1020]
# loss: 2.003275    [  672/ 1020]
#
# Avg train loss: 2.043137
# Train accuracy = 47.5%
# Accuracy on validation set = 31.1%
# Average loss on validation set = 2.806205853819847
#
# Epoch 11
# loss: 2.289052    [   32/ 1020]
# loss: 2.322955    [  672/ 1020]
#
# Avg train loss: 2.049795
# Train accuracy = 45.9%
# Accuracy on validation set = 31.9%
# Average loss on validation set = 2.777882419526577
#
# Epoch 12
# loss: 2.672438    [   32/ 1020]
# loss: 2.442144    [  672/ 1020]
#
# Avg train loss: 2.062292
# Train accuracy = 46.6%
# Accuracy on validation set = 31.3%
# Average loss on validation set = 2.771046280860901
#
# Epoch 13
# loss: 1.874925    [   32/ 1020]
# loss: 2.213523    [  672/ 1020]
#
# Avg train loss: 2.036358
# Train accuracy = 47.3%
# Accuracy on validation set = 33.1%
# Average loss on validation set = 2.7477842420339584
#
# Epoch 14
# loss: 2.255103    [   32/ 1020]
# loss: 1.967883    [  672/ 1020]
#
# Avg train loss: 2.026379
# Train accuracy = 48.0%
# Accuracy on validation set = 32.2%
# Average loss on validation set = 2.768425092101097
#
# Epoch 15
# loss: 2.007428    [   32/ 1020]
# loss: 2.105525    [  672/ 1020]
#
# Avg train loss: 2.026118
# Train accuracy = 47.2%
# Accuracy on validation set = 32.6%
# Average loss on validation set = 2.766884319484234
#
# Epoch 16
# loss: 1.856198    [   32/ 1020]
# loss: 2.360823    [  672/ 1020]
#
# Avg train loss: 2.013834
# Train accuracy = 49.3%
# Accuracy on validation set = 32.4%
# Average loss on validation set = 2.76425027102232
#
# Epoch 17
# loss: 2.148084    [   32/ 1020]
# loss: 2.106467    [  672/ 1020]
#
# Avg train loss: 1.986522
# Train accuracy = 47.5%
# Accuracy on validation set = 32.4%
# Average loss on validation set = 2.76577877253294
#
# Epoch 18
# loss: 2.329340    [   32/ 1020]
# loss: 1.910637    [  672/ 1020]
#
# Avg train loss: 1.995510
# Train accuracy = 51.6%
# Accuracy on validation set = 31.9%
# Average loss on validation set = 2.7827714905142784
#
# Epoch 19
# loss: 1.948628    [   32/ 1020]
# loss: 1.975890    [  672/ 1020]
#
# Avg train loss: 1.972302
# Train accuracy = 50.4%
# Accuracy on validation set = 32.6%
# Average loss on validation set = 2.7511377185583115
#
# Epoch 20
# loss: 2.302447    [   32/ 1020]
# loss: 1.810046    [  672/ 1020]
#
# Avg train loss: 1.938751
# Train accuracy = 51.5%
# Accuracy on validation set = 32.8%
# Average loss on validation set = 2.742608495056629
#
# Epoch 21
# loss: 1.845161    [   32/ 1020]
# loss: 1.917922    [  672/ 1020]
#
# Avg train loss: 1.887199
# Train accuracy = 53.8%
# Accuracy on validation set = 33.3%
# Average loss on validation set = 2.7599074244499207
#
# Epoch 22
# loss: 1.811756    [   32/ 1020]
# loss: 1.760599    [  672/ 1020]
#
# Avg train loss: 1.889266
# Train accuracy = 53.6%
# Accuracy on validation set = 32.5%
# Average loss on validation set = 2.7409183233976364
#
# Epoch 23
# loss: 1.833992    [   32/ 1020]
# loss: 1.881263    [  672/ 1020]
#
# Avg train loss: 1.894553
# Train accuracy = 53.4%
# Accuracy on validation set = 34.4%
# Average loss on validation set = 2.740803338587284
#
# Epoch 24
# loss: 1.768035    [   32/ 1020]
# loss: 2.012438    [  672/ 1020]
#
# Avg train loss: 1.867395
# Train accuracy = 52.4%
# Accuracy on validation set = 32.8%
# Average loss on validation set = 2.7549548596143723
#
# Epoch 25
# loss: 1.771072    [   32/ 1020]
# loss: 1.895484    [  672/ 1020]
#
# Avg train loss: 1.853689
# Train accuracy = 53.7%
# Accuracy on validation set = 34.2%
# Average loss on validation set = 2.709405690431595
#
# Epoch 26
# loss: 1.805126    [   32/ 1020]
# loss: 2.166368    [  672/ 1020]
#
# Avg train loss: 1.876137
# Train accuracy = 52.5%
# Accuracy on validation set = 34.0%
# Average loss on validation set = 2.7062334045767784
#
# Epoch 27
# loss: 1.827275    [   32/ 1020]
# loss: 1.887896    [  672/ 1020]
#
# Avg train loss: 1.804239
# Train accuracy = 55.4%
# Accuracy on validation set = 34.1%
# Average loss on validation set = 2.751915343105793
#
# Epoch 28
# loss: 1.902437    [   32/ 1020]
# loss: 1.693980    [  672/ 1020]
#
# Avg train loss: 1.811080
# Train accuracy = 54.3%
# Accuracy on validation set = 34.1%
# Average loss on validation set = 2.7073231264948845
#
# Epoch 29
# loss: 1.710721    [   32/ 1020]
# loss: 1.773552    [  672/ 1020]
#
# Avg train loss: 1.849186
# Train accuracy = 53.0%
# Accuracy on validation set = 33.0%
# Average loss on validation set = 2.721685692667961
#
# Epoch 30
# loss: 1.688413    [   32/ 1020]
# loss: 1.850372    [  672/ 1020]
#
# Avg train loss: 1.770430
# Train accuracy = 55.6%
# Accuracy on validation set = 34.2%
# Average loss on validation set = 2.7293360605835915
#
# Epoch 31
# loss: 1.564737    [   32/ 1020]
# loss: 2.140323    [  672/ 1020]
#
# Avg train loss: 1.782924
# Train accuracy = 57.4%
# Accuracy on validation set = 34.7%
# Average loss on validation set = 2.6908030286431313
#
# Epoch 32
# loss: 1.722278    [   32/ 1020]
# loss: 1.607586    [  672/ 1020]
#
# Avg train loss: 1.789423
# Train accuracy = 56.1%
# Accuracy on validation set = 34.1%
# Average loss on validation set = 2.7044587880373
#
# Epoch 33
# loss: 1.628530    [   32/ 1020]
# loss: 1.663157    [  672/ 1020]
#
# Avg train loss: 1.727824
# Train accuracy = 57.3%
# Accuracy on validation set = 35.1%
# Average loss on validation set = 2.6785290837287903
#
# Epoch 34
# loss: 1.671372    [   32/ 1020]
# loss: 1.599399    [  672/ 1020]
#
# Avg train loss: 1.760124
# Train accuracy = 53.0%
# Accuracy on validation set = 34.7%
# Average loss on validation set = 2.6783732548356056
#
# Epoch 35
# loss: 1.756316    [   32/ 1020]
# loss: 1.679577    [  672/ 1020]
#
# Avg train loss: 1.775778
# Train accuracy = 54.9%
# Accuracy on validation set = 34.9%
# Average loss on validation set = 2.684026040136814
#
# Epoch 36
# loss: 1.647821    [   32/ 1020]
# loss: 1.680867    [  672/ 1020]
#
# Avg train loss: 1.756116
# Train accuracy = 58.0%
# Accuracy on validation set = 35.7%
# Average loss on validation set = 2.675410009920597
#
# Epoch 37
# loss: 1.783700    [   32/ 1020]
# loss: 1.596558    [  672/ 1020]
#
# Avg train loss: 1.745808
# Train accuracy = 58.1%
# Accuracy on validation set = 35.3%
# Average loss on validation set = 2.6728292107582092
#
# Epoch 38
# loss: 1.960159    [   32/ 1020]
# loss: 1.622004    [  672/ 1020]
#
# Avg train loss: 1.714719
# Train accuracy = 57.5%
# Accuracy on validation set = 34.8%
# Average loss on validation set = 2.6859964951872826
#
# Epoch 39
# loss: 1.866860    [   32/ 1020]
# loss: 1.726034    [  672/ 1020]
#
# Avg train loss: 1.721951
# Train accuracy = 56.9%
# Accuracy on validation set = 34.1%
# Average loss on validation set = 2.6802779734134674
#
# Epoch 40
# loss: 1.779513    [   32/ 1020]
# loss: 1.557176    [  672/ 1020]
#
# Avg train loss: 1.733637
# Train accuracy = 57.1%
# Accuracy on validation set = 34.9%
# Average loss on validation set = 2.6762723214924335
#
# Epoch 41
# loss: 1.664655    [   32/ 1020]
# loss: 1.967900    [  672/ 1020]
#
# Avg train loss: 1.699084
# Train accuracy = 58.3%
# Accuracy on validation set = 35.0%
# Average loss on validation set = 2.6706419847905636
#
# Epoch 42
# loss: 1.761038    [   32/ 1020]
# loss: 1.881347    [  672/ 1020]
#
# Avg train loss: 1.740568
# Train accuracy = 56.8%
# Accuracy on validation set = 35.0%
# Average loss on validation set = 2.702244885265827
#
# Epoch 43
# loss: 1.697089    [   32/ 1020]
# loss: 1.735775    [  672/ 1020]
#
# Avg train loss: 1.711050
# Train accuracy = 59.9%
# Accuracy on validation set = 35.1%
# Average loss on validation set = 2.709044873714447
#
# Epoch 44
# loss: 1.459299    [   32/ 1020]
# loss: 1.739169    [  672/ 1020]
#
# Avg train loss: 1.699467
# Train accuracy = 57.6%
# Accuracy on validation set = 36.0%
# Average loss on validation set = 2.683294825255871
#
# Epoch 45
# loss: 1.447582    [   32/ 1020]
# loss: 1.349359    [  672/ 1020]
#
# Avg train loss: 1.679460
# Train accuracy = 57.1%
# Accuracy on validation set = 35.1%
# Average loss on validation set = 2.685986489057541
#
# Epoch 46
# loss: 1.654838    [   32/ 1020]
# loss: 1.522012    [  672/ 1020]
#
# Avg train loss: 1.691914
# Train accuracy = 59.1%
# Accuracy on validation set = 35.1%
# Average loss on validation set = 2.6753051355481148
#
# Epoch 47
# loss: 1.763140    [   32/ 1020]
# loss: 1.632551    [  672/ 1020]
#
# Avg train loss: 1.680975
# Train accuracy = 59.3%
# Accuracy on validation set = 35.2%
# Average loss on validation set = 2.6886839382350445
#
# Epoch 48
# loss: 1.564821    [   32/ 1020]
# loss: 1.726940    [  672/ 1020]
#
# Avg train loss: 1.700998
# Train accuracy = 56.5%
# Accuracy on validation set = 36.3%
# Average loss on validation set = 2.6763008683919907
#
# Epoch 49
# loss: 1.551351    [   32/ 1020]
# loss: 1.618716    [  672/ 1020]
#
# Avg train loss: 1.687170
# Train accuracy = 59.8%
# Accuracy on validation set = 35.8%
# Average loss on validation set = 2.6794766411185265
#
# Epoch 50
# loss: 1.563031    [   32/ 1020]
# loss: 1.844314    [  672/ 1020]
#
# Avg train loss: 1.669923
# Train accuracy = 60.3%
# Accuracy on validation set = 36.5%
# Average loss on validation set = 2.6680129170417786

# %%
from google.colab import drive
drive.mount('/content/drive')
torch.save(
    model.state_dict(), 
    "/content/drive/Shareddrives/INT2 Group 12/NeuralNetwork.pth"
    )
# Out:
# Mounted at /content/drive

# %%
#plot the loss and accuracy of the training and validation set
plt.plot(epochCountList, epochTrainLoss, label="Training loss")
plt.plot(epochCountList, epochValLoss, label="Validation loss")
plt.title("Train & validation loss")
plt.legend()
plt.show()

plt.plot(epochCountList, epochTrainAccuracy, label="Training accuracy")
plt.plot(epochCountList, epochValAccuracy, label="Validation accuracy")
plt.title("Train & validation accuracy")
plt.legend()
plt.show()

# %%
#Save the model to the drive
PATH ="./NeuralNetwork.pth"
torch.save(model.state_dict(), PATH)

# %%
#Run the model on the test set
test(testDataloader, model)
