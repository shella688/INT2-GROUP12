# %%
#imports
import math
#PyTorch imports
import torch
import torch.nn as nn
from torch.optim import AdamW
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

#Import SciPy to load the Flowers-102 dataset from the .mat format
import scipy.io

#Other imports
import numpy as np
import matplotlib.pyplot as plt

#Import time so that we can train the model within the 12 hour time limit
import time

# %%
#Define transforms
trainingTransform = transforms.Compose([
    transforms.Resize(224), #Change this value to edit the image size
    transforms.CenterCrop(224), #Must be the same as resize value. This is used to ensure the image is square
    #Default probability for both flips is p=0.5, can be changed if needed
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    #Rotates each image by a random angle between 0-90 degrees
    transforms.RandomRotation(90),
    #TODO: Find out how to apply this transformation randomly
    # (note from Olivia, use the range! satruation can go High but
    # then the images look weird, hsue has to be between -0.5-0.5)
    #transforms.ColorJitter(saturation=[0, 5], hue=(-0.5, 0.5)),
    transforms.ToTensor(),
    transforms.Normalize(0,1) #zerocenter normalization
])

nonTrainTransform = transforms.Compose([
    #Same as training transform without flipping as required
    #by assessment rules
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(0,1)
])

#Load Flowers-102 dataset and split it into train, validate and test splits
trainingSet = datasets.Flowers102(root="./flowers", split="train", download=True, transform=trainingTransform)
validationSet = datasets.Flowers102(root="./flowers", split="val", download=True, transform=nonTrainTransform)
testingSet = datasets.Flowers102(root="./flowers", split="test", download=True, transform=nonTrainTransform)

# %%
#Checking the splits are the correct length
print(len(trainingSet))
print(len(validationSet))
print(len(testingSet))
# Out:
# 1020
# 1020
# 6149

# %%
#Checking the training transformations are ok
figure = plt.figure(figsize=(10,10))
col, row = 2, 2
for i in range(1, 5): #TODO: Change this to be rows * columns
  randImg = torch.randint(len(trainingSet), size=(1,)).item() #Size defines the shape of the tensor
  img, label = trainingSet[randImg]
  figure.add_subplot(row, col, i)
  plt.title(label)
  plt.axis(False)
  plt.imshow(img.squeeze().permute(1,2,0)) #Permute gets the dimentions in the correct order
plt.show()

# %%
#Checking if collab can connect to a GPU
if torch.cuda.is_available():
  device = torch.device('cuda:0')
else:
  device = torch.device('cpu')

# %%
#The CNN itself
class CNN(nn.Module):
  def __init__(self):
    super().__init__()
    #DEFINING THE LAYERS. THIS IS WHERE WE WILL SPEND MOST OF OUR TIME
    self.netLayers = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(2,2),
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=(1,1), padding=1),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Dropout(0.15),
        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        nn.AvgPool2d(2,2),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(256),
        #nn.LeakyReLU(), #LeakyReLU is used to prevent 'dead ReLU' issues
        nn.ReLU(),
        nn.Dropout(0.15),
        nn.MaxPool2d(2,2),
        nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.MaxPool2d(2,2),
        nn.Flatten(),
        #IMPORTANT: in channels for first linear must be
        # (image size) * (image size) * C
        #Where C is the out channels of the last conv2d
        #If confused, just print out the shape of the matrix
        nn.Linear(100352, 128),
        nn.BatchNorm1d(128),
        nn.Linear(128, 64),
        nn.Dropout(0.05),
        nn.Linear(64, 102), #102 for the classifiers
        nn.LogSoftmax(dim=1)
    )
  
  def forward(self, x):
      result = self.netLayers(x)
      #print(result.shape)
      return result

# %%
#TODO: Code to train the CNN on the training set for a set amount of minutes.
def timedTrain(minutes, cnn, lossFunction, optimiser, showGraph):
  startTime = time.time()
  endTime = time.time() + (minutes * 60)
  trainingError = []

# %%
#Code to train the CNN based on a set number of epochs
def epochCountTrain(trainLoader, cnn, optimizer, lossFunction):
  totalLoss, correct = 0, 0
  size = len(trainLoader.dataset)
  for i, data in enumerate(trainLoader, 0):
    input, labels = data
    input = input.to(device)
    labels = labels.to(device)
    optimizer.zero_grad()
    output = cnn(input)
    loss = lossFunction(output, labels)
    loss.backward()
    optimizer.step()
    totalLoss += loss.item()
    correct += (output.argmax(1)==labels).sum().item()
    if i % 20 == 0:
      loss, currentLoss = loss.item(), (i + 1) * len(input)
      print(f"loss: {loss:>7f}    [{currentLoss:>5d}/{size:>5d}]")
  print(f"\n Avg train loss: {(totalLoss/len(trainLoader)):>8f}")
  print(f"Test accuarcy = {((correct/1020) * 100): >0.1f}%")

# %%
#Code to guess accuracy based on validation set
def validation(valLoader, cnn, lossFunction):
  valSize = len(valLoader.dataset)
  correct = 0
  loss = []
  with torch.no_grad(): #as we are not calling backward, use no grad to save memory
    for batch in valLoader:
      input, labels = batch
      input = input.to(device)
      labels = labels.to(device)
      prediciton = cnn(input)
      loss.append(lossFunction(prediciton, labels).item())
      correct += (prediciton.argmax(1) == labels).sum().item()
  
  print(f"Accuracy on validation set = {((correct / valSize) * 100):>0.1f}%")
  print(f"Average loss on validation set = {(np.average(loss))}")

# %%
#Actual code to get it all running
epochCount = 100
learningRate = 0.00005
batchSize = 32
lossFunction = nn.CrossEntropyLoss()
model = CNN().to(device)
optimizer = AdamW(lr=learningRate, params=model.parameters(), weight_decay=0.1)
trainDataloader = DataLoader(trainingSet, batch_size=batchSize, shuffle=True)
valDataloader = DataLoader(validationSet, batch_size=batchSize, shuffle=True)
for i in range(epochCount):
  print(f"Epoch {i}")
  model.train()
  epochCountTrain(trainDataloader, model, optimizer, lossFunction)
  model.eval()
  validation(valDataloader, model, lossFunction)
# Out:
# Epoch 0
# loss: 4.655429    [   32/ 1020]
# loss: 4.335301    [  672/ 1020]
#
#  Avg train loss: 4.365114
# Test accuarcy = 5.0%
# Accuracy on validation set = 0.4%
# Average loss on validation set = 4.747262433171272
# Epoch 1
# loss: 4.068168    [   32/ 1020]
# loss: 4.086374    [  672/ 1020]
#
#  Avg train loss: 4.041153
# Test accuarcy = 12.8%
# Accuracy on validation set = 6.3%
# Average loss on validation set = 4.305516615509987
# Epoch 2
# loss: 3.737636    [   32/ 1020]
# loss: 3.975258    [  672/ 1020]
#
#  Avg train loss: 3.875981
# Test accuarcy = 16.3%
# Accuracy on validation set = 11.3%
# Average loss on validation set = 4.0662055388092995
# Epoch 3
# loss: 3.554561    [   32/ 1020]
# loss: 3.881721    [  672/ 1020]
#
#  Avg train loss: 3.754065
# Test accuarcy = 20.2%
# Accuracy on validation set = 13.9%
# Average loss on validation set = 3.991108812391758
# Epoch 4
# loss: 3.533789    [   32/ 1020]
# loss: 3.804242    [  672/ 1020]
#
#  Avg train loss: 3.658689
# Test accuarcy = 24.5%
# Accuracy on validation set = 16.8%
# Average loss on validation set = 3.889216810464859
# Epoch 5
# loss: 3.483641    [   32/ 1020]
# loss: 3.391827    [  672/ 1020]
#
#  Avg train loss: 3.548695
# Test accuarcy = 29.9%
# Accuracy on validation set = 18.3%
# Average loss on validation set = 3.921616591513157
# Epoch 6
# loss: 3.464863    [   32/ 1020]
# loss: 3.387483    [  672/ 1020]
#
#  Avg train loss: 3.471737
# Test accuarcy = 31.8%
# Accuracy on validation set = 20.4%
# Average loss on validation set = 3.8264408484101295
# Epoch 7
# loss: 3.435270    [   32/ 1020]
# loss: 3.434214    [  672/ 1020]
#
#  Avg train loss: 3.377919
# Test accuarcy = 34.0%
# Accuracy on validation set = 20.2%
# Average loss on validation set = 3.8373001143336296
# Epoch 8
# loss: 2.837148    [   32/ 1020]
# loss: 3.330389    [  672/ 1020]
#
#  Avg train loss: 3.298676
# Test accuarcy = 39.2%
# Accuracy on validation set = 22.0%
# Average loss on validation set = 3.755558617413044
# Epoch 9
# loss: 3.146219    [   32/ 1020]
# loss: 3.095506    [  672/ 1020]
#
#  Avg train loss: 3.221859
# Test accuarcy = 40.7%
# Accuracy on validation set = 24.2%
# Average loss on validation set = 3.7304272204637527
# Epoch 10
# loss: 3.145148    [   32/ 1020]
# loss: 3.326607    [  672/ 1020]
#
#  Avg train loss: 3.160893
# Test accuarcy = 44.1%
# Accuracy on validation set = 24.6%
# Average loss on validation set = 3.6728443428874016
# Epoch 11
# loss: 2.868068    [   32/ 1020]
# loss: 3.068150    [  672/ 1020]
#
#  Avg train loss: 3.066580
# Test accuarcy = 47.0%
# Accuracy on validation set = 27.6%
# Average loss on validation set = 3.660462476313114
# Epoch 12
# loss: 2.811366    [   32/ 1020]
# loss: 3.090714    [  672/ 1020]
#
#  Avg train loss: 3.042724
# Test accuarcy = 46.9%
# Accuracy on validation set = 27.3%
# Average loss on validation set = 3.6339483857154846
# Epoch 13
# loss: 2.893616    [   32/ 1020]
# loss: 2.805046    [  672/ 1020]
#
#  Avg train loss: 2.974892
# Test accuarcy = 48.8%
# Accuracy on validation set = 27.0%
# Average loss on validation set = 3.564414031803608
# Epoch 14
# loss: 3.027841    [   32/ 1020]
# loss: 2.629935    [  672/ 1020]
#
#  Avg train loss: 2.884518
# Test accuarcy = 53.5%
# Accuracy on validation set = 27.5%
# Average loss on validation set = 3.602599523961544
# Epoch 15
# loss: 2.880598    [   32/ 1020]
# loss: 2.950809    [  672/ 1020]
#
#  Avg train loss: 2.829961
# Test accuarcy = 52.7%
# Accuracy on validation set = 28.8%
# Average loss on validation set = 3.5479282587766647
# Epoch 16
# loss: 2.990630    [   32/ 1020]
# loss: 2.786826    [  672/ 1020]
#
#  Avg train loss: 2.756517
# Test accuarcy = 54.7%
# Accuracy on validation set = 29.6%
# Average loss on validation set = 3.5148097053170204
# Epoch 17
# loss: 2.911711    [   32/ 1020]
# loss: 2.515800    [  672/ 1020]
#
#  Avg train loss: 2.699698
# Test accuarcy = 57.4%
# Accuracy on validation set = 27.3%
# Average loss on validation set = 3.4904855713248253
# Epoch 18
# loss: 2.506019    [   32/ 1020]
# loss: 2.847732    [  672/ 1020]
#
#  Avg train loss: 2.660691
# Test accuarcy = 57.2%
# Accuracy on validation set = 25.0%
# Average loss on validation set = 3.5339192152023315
# Epoch 19
# loss: 2.344076    [   32/ 1020]
# loss: 2.571999    [  672/ 1020]
#
#  Avg train loss: 2.569561
# Test accuarcy = 61.5%
# Accuracy on validation set = 31.4%
# Average loss on validation set = 3.362171858549118
# Epoch 20
# loss: 2.270997    [   32/ 1020]
# loss: 2.344336    [  672/ 1020]
#
#  Avg train loss: 2.501864
# Test accuarcy = 62.6%
# Accuracy on validation set = 32.0%
# Average loss on validation set = 3.3463626727461815
# Epoch 21
# loss: 2.504607    [   32/ 1020]
# loss: 2.538050    [  672/ 1020]
#
#  Avg train loss: 2.439663
# Test accuarcy = 62.9%
# Accuracy on validation set = 34.0%
# Average loss on validation set = 3.3081177920103073
# Epoch 22
# loss: 2.390679    [   32/ 1020]
# loss: 2.426334    [  672/ 1020]
#
#  Avg train loss: 2.346628
# Test accuarcy = 67.5%
# Accuracy on validation set = 33.3%
# Average loss on validation set = 3.304890640079975
# Epoch 23
# loss: 2.098318    [   32/ 1020]
# loss: 2.385668    [  672/ 1020]
#
#  Avg train loss: 2.336483
# Test accuarcy = 65.9%
# Accuracy on validation set = 33.0%
# Average loss on validation set = 3.2641213834285736
# Epoch 24
# loss: 2.292893    [   32/ 1020]
# loss: 1.932353    [  672/ 1020]
#
#  Avg train loss: 2.295350
# Test accuarcy = 67.0%
# Accuracy on validation set = 32.1%
# Average loss on validation set = 3.2850894033908844
# Epoch 25
# loss: 2.227802    [   32/ 1020]
# loss: 2.291151    [  672/ 1020]
#
#  Avg train loss: 2.199996
# Test accuarcy = 70.0%
# Accuracy on validation set = 31.5%
# Average loss on validation set = 3.255977213382721
# Epoch 26
# loss: 1.800686    [   32/ 1020]
# loss: 2.464525    [  672/ 1020]
#
#  Avg train loss: 2.104836
# Test accuarcy = 72.2%
# Accuracy on validation set = 34.3%
# Average loss on validation set = 3.192013770341873
# Epoch 27
# loss: 2.295217    [   32/ 1020]
# loss: 2.448681    [  672/ 1020]
#
#  Avg train loss: 2.128683
# Test accuarcy = 70.9%
# Accuracy on validation set = 33.7%
# Average loss on validation set = 3.209422282874584
# Epoch 28
# loss: 1.945471    [   32/ 1020]
# loss: 2.018671    [  672/ 1020]
#
#  Avg train loss: 2.035863
# Test accuarcy = 74.0%
# Accuracy on validation set = 33.8%
# Average loss on validation set = 3.2016723304986954
# Epoch 29
# loss: 1.824223    [   32/ 1020]
# loss: 1.798831    [  672/ 1020]
#
#  Avg train loss: 2.005220
# Test accuarcy = 74.4%
# Accuracy on validation set = 35.3%
# Average loss on validation set = 3.105289041996002
# Epoch 30
# loss: 1.876190    [   32/ 1020]
# loss: 1.951763    [  672/ 1020]
#
#  Avg train loss: 1.911999
# Test accuarcy = 75.8%
# Accuracy on validation set = 38.0%
# Average loss on validation set = 3.1218630522489548
# Epoch 31
# loss: 1.663010    [   32/ 1020]
# loss: 2.210181    [  672/ 1020]
#
#  Avg train loss: 1.868090
# Test accuarcy = 79.7%
# Accuracy on validation set = 37.7%
# Average loss on validation set = 3.0457859560847282
# Epoch 32
# loss: 1.942023    [   32/ 1020]
# loss: 1.825649    [  672/ 1020]
#
#  Avg train loss: 1.807094
# Test accuarcy = 79.2%
# Accuracy on validation set = 35.5%
# Average loss on validation set = 3.0561270341277122
# Epoch 33
# loss: 1.857505    [   32/ 1020]
# loss: 1.693817    [  672/ 1020]
#
#  Avg train loss: 1.768162
# Test accuarcy = 79.5%
# Accuracy on validation set = 36.2%
# Average loss on validation set = 3.085301451385021
# Epoch 34
# loss: 1.856257    [   32/ 1020]
# loss: 1.768808    [  672/ 1020]
#
#  Avg train loss: 1.684897
# Test accuarcy = 82.5%
# Accuracy on validation set = 38.3%
# Average loss on validation set = 3.023701786994934
# Epoch 35
# loss: 1.641305    [   32/ 1020]
# loss: 1.620999    [  672/ 1020]
#
#  Avg train loss: 1.629799
# Test accuarcy = 82.1%
# Accuracy on validation set = 38.8%
# Average loss on validation set = 3.0166667327284813
# Epoch 36
# loss: 1.694087    [   32/ 1020]
# loss: 1.714385    [  672/ 1020]
#
#  Avg train loss: 1.584642
# Test accuarcy = 81.4%
# Accuracy on validation set = 39.8%
# Average loss on validation set = 3.0069368183612823
# Epoch 37
# loss: 1.626492    [   32/ 1020]
# loss: 1.801637    [  672/ 1020]
#
#  Avg train loss: 1.567368
# Test accuarcy = 83.3%
# Accuracy on validation set = 39.4%
# Average loss on validation set = 2.951756976544857
# Epoch 38
# loss: 1.481994    [   32/ 1020]
# loss: 1.634409    [  672/ 1020]
#
#  Avg train loss: 1.498156
# Test accuarcy = 85.2%
# Accuracy on validation set = 35.8%
# Average loss on validation set = 2.9777636155486107
# Epoch 39
# loss: 1.272624    [   32/ 1020]
# loss: 1.602882    [  672/ 1020]
#
#  Avg train loss: 1.428473
# Test accuarcy = 87.7%
# Accuracy on validation set = 38.5%
# Average loss on validation set = 2.951337344944477
# Epoch 40
# loss: 1.635025    [   32/ 1020]
# loss: 1.394662    [  672/ 1020]
#
#  Avg train loss: 1.401798
# Test accuarcy = 87.4%
# Accuracy on validation set = 38.3%
# Average loss on validation set = 2.9070939496159554
# Epoch 41
# loss: 1.159545    [   32/ 1020]
# loss: 1.242190    [  672/ 1020]
#
#  Avg train loss: 1.357178
# Test accuarcy = 87.2%
# Accuracy on validation set = 37.7%
# Average loss on validation set = 2.9510838761925697
# Epoch 42
# loss: 1.304917    [   32/ 1020]
# loss: 1.260086    [  672/ 1020]
#
#  Avg train loss: 1.291327
# Test accuarcy = 90.2%
# Accuracy on validation set = 38.0%
# Average loss on validation set = 2.9393455907702446
# Epoch 43
# loss: 1.481484    [   32/ 1020]
# loss: 1.328015    [  672/ 1020]
#
#  Avg train loss: 1.218092
# Test accuarcy = 89.8%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.834662824869156
# Epoch 44
# loss: 1.044671    [   32/ 1020]
# loss: 1.071922    [  672/ 1020]
#
#  Avg train loss: 1.210033
# Test accuarcy = 90.2%
# Accuracy on validation set = 38.7%
# Average loss on validation set = 2.890477292239666
# Epoch 45
# loss: 1.144899    [   32/ 1020]
# loss: 1.178550    [  672/ 1020]
#
#  Avg train loss: 1.192271
# Test accuarcy = 90.1%
# Accuracy on validation set = 39.3%
# Average loss on validation set = 2.842345207929611
# Epoch 46
# loss: 1.105559    [   32/ 1020]
# loss: 1.015973    [  672/ 1020]
#
#  Avg train loss: 1.128471
# Test accuarcy = 90.7%
# Accuracy on validation set = 37.2%
# Average loss on validation set = 2.896463170647621
# Epoch 47
# loss: 0.943383    [   32/ 1020]
# loss: 1.079598    [  672/ 1020]
#
#  Avg train loss: 1.103611
# Test accuarcy = 91.7%
# Accuracy on validation set = 39.1%
# Average loss on validation set = 2.8654932901263237
# Epoch 48
# loss: 0.983695    [   32/ 1020]
# loss: 0.832732    [  672/ 1020]
#
#  Avg train loss: 1.058571
# Test accuarcy = 93.0%
# Accuracy on validation set = 38.9%
# Average loss on validation set = 2.7726811692118645
# Epoch 49
# loss: 0.764135    [   32/ 1020]
# loss: 0.881912    [  672/ 1020]
#
#  Avg train loss: 0.990128
# Test accuarcy = 93.6%
# Accuracy on validation set = 40.5%
# Average loss on validation set = 2.7896996214985847
# Epoch 50
# loss: 0.667079    [   32/ 1020]
# loss: 1.096651    [  672/ 1020]
#
#  Avg train loss: 0.956716
# Test accuarcy = 94.5%
# Accuracy on validation set = 41.5%
# Average loss on validation set = 2.7802723720669746
# Epoch 51
# loss: 0.759744    [   32/ 1020]
# loss: 0.894381    [  672/ 1020]
#
#  Avg train loss: 0.914036
# Test accuarcy = 94.6%
# Accuracy on validation set = 40.0%
# Average loss on validation set = 2.783234514296055
# Epoch 52
# loss: 1.098151    [   32/ 1020]
# loss: 0.763072    [  672/ 1020]
#
#  Avg train loss: 0.892890
# Test accuarcy = 95.1%
# Accuracy on validation set = 40.3%
# Average loss on validation set = 2.8012857735157013
# Epoch 53
# loss: 0.828349    [   32/ 1020]
# loss: 0.893738    [  672/ 1020]
#
#  Avg train loss: 0.861803
# Test accuarcy = 95.0%
# Accuracy on validation set = 39.3%
# Average loss on validation set = 2.8187790289521217
# Epoch 54
# loss: 0.656109    [   32/ 1020]
# loss: 0.730642    [  672/ 1020]
#
#  Avg train loss: 0.792675
# Test accuarcy = 96.2%
# Accuracy on validation set = 40.1%
# Average loss on validation set = 2.753012180328369
# Epoch 55
# loss: 0.701388    [   32/ 1020]
# loss: 0.697314    [  672/ 1020]
#
#  Avg train loss: 0.783622
# Test accuarcy = 96.5%
# Accuracy on validation set = 40.5%
# Average loss on validation set = 2.776517502963543
# Epoch 56
# loss: 0.583665    [   32/ 1020]
# loss: 0.736025    [  672/ 1020]
#
#  Avg train loss: 0.743686
# Test accuarcy = 96.7%
# Accuracy on validation set = 41.1%
# Average loss on validation set = 2.760342448949814
# Epoch 57
# loss: 0.727340    [   32/ 1020]
# loss: 0.859492    [  672/ 1020]
#
#  Avg train loss: 0.681938
# Test accuarcy = 97.5%
# Accuracy on validation set = 41.2%
# Average loss on validation set = 2.756261184811592
# Epoch 58
# loss: 0.651191    [   32/ 1020]
# loss: 0.728290    [  672/ 1020]
#
#  Avg train loss: 0.677792
# Test accuarcy = 96.8%
# Accuracy on validation set = 42.8%
# Average loss on validation set = 2.734283111989498
# Epoch 59
# loss: 0.640994    [   32/ 1020]
# loss: 0.634196    [  672/ 1020]
#
#  Avg train loss: 0.657878
# Test accuarcy = 96.6%
# Accuracy on validation set = 40.2%
# Average loss on validation set = 2.7503645345568657
# Epoch 60
# loss: 0.718716    [   32/ 1020]
# loss: 0.601911    [  672/ 1020]
#
#  Avg train loss: 0.646366
# Test accuarcy = 97.5%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.7106188908219337
# Epoch 61
# loss: 0.474993    [   32/ 1020]
# loss: 0.516840    [  672/ 1020]
#
#  Avg train loss: 0.574907
# Test accuarcy = 97.9%
# Accuracy on validation set = 41.7%
# Average loss on validation set = 2.7151910699903965
# Epoch 62
# loss: 0.544003    [   32/ 1020]
# loss: 0.500192    [  672/ 1020]
#
#  Avg train loss: 0.586042
# Test accuarcy = 97.6%
# Accuracy on validation set = 41.2%
# Average loss on validation set = 2.8044847771525383
# Epoch 63
# loss: 0.517107    [   32/ 1020]
# loss: 0.523478    [  672/ 1020]
#
#  Avg train loss: 0.560351
# Test accuarcy = 97.8%
# Accuracy on validation set = 41.3%
# Average loss on validation set = 2.726769495755434
# Epoch 64
# loss: 0.469496    [   32/ 1020]
# loss: 0.508394    [  672/ 1020]
#
#  Avg train loss: 0.532102
# Test accuarcy = 98.4%
# Accuracy on validation set = 42.3%
# Average loss on validation set = 2.716031663119793
# Epoch 65
# loss: 0.649955    [   32/ 1020]
# loss: 0.367928    [  672/ 1020]
#
#  Avg train loss: 0.515258
# Test accuarcy = 97.7%
# Accuracy on validation set = 41.5%
# Average loss on validation set = 2.6828851848840714
# Epoch 66
# loss: 0.419178    [   32/ 1020]
# loss: 0.491878    [  672/ 1020]
#
#  Avg train loss: 0.472315
# Test accuarcy = 98.6%
# Accuracy on validation set = 40.3%
# Average loss on validation set = 2.7249001786112785
# Epoch 67
# loss: 0.545419    [   32/ 1020]
# loss: 0.424727    [  672/ 1020]
#
#  Avg train loss: 0.472141
# Test accuarcy = 98.2%
# Accuracy on validation set = 41.3%
# Average loss on validation set = 2.715151362121105
# Epoch 68
# loss: 0.490190    [   32/ 1020]
# loss: 0.478667    [  672/ 1020]
#
#  Avg train loss: 0.430870
# Test accuarcy = 99.2%
# Accuracy on validation set = 42.0%
# Average loss on validation set = 2.6514295414090157
# Epoch 69
# loss: 0.385722    [   32/ 1020]
# loss: 0.351307    [  672/ 1020]
#
#  Avg train loss: 0.415904
# Test accuarcy = 99.2%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.6823692098259926
# Epoch 70
# loss: 0.363237    [   32/ 1020]
# loss: 0.509670    [  672/ 1020]
#
#  Avg train loss: 0.408817
# Test accuarcy = 99.0%
# Accuracy on validation set = 42.3%
# Average loss on validation set = 2.6842575520277023
# Epoch 71
# loss: 0.439815    [   32/ 1020]
# loss: 0.325159    [  672/ 1020]
#
#  Avg train loss: 0.393307
# Test accuarcy = 98.9%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.6720935851335526
# Epoch 72
# loss: 0.389645    [   32/ 1020]
# loss: 0.290937    [  672/ 1020]
#
#  Avg train loss: 0.354284
# Test accuarcy = 99.8%
# Accuracy on validation set = 42.5%
# Average loss on validation set = 2.604790799319744
# Epoch 73
# loss: 0.313965    [   32/ 1020]
# loss: 0.350199    [  672/ 1020]
#
#  Avg train loss: 0.329530
# Test accuarcy = 99.4%
# Accuracy on validation set = 40.3%
# Average loss on validation set = 2.667824748903513
# Epoch 74
# loss: 0.370200    [   32/ 1020]
# loss: 0.334943    [  672/ 1020]
#
#  Avg train loss: 0.328871
# Test accuarcy = 99.7%
# Accuracy on validation set = 41.4%
# Average loss on validation set = 2.6342523358762264
# Epoch 75
# loss: 0.276931    [   32/ 1020]
# loss: 0.352084    [  672/ 1020]
#
#  Avg train loss: 0.331580
# Test accuarcy = 99.1%
# Accuracy on validation set = 40.9%
# Average loss on validation set = 2.692427523434162
# Epoch 76
# loss: 0.266546    [   32/ 1020]
# loss: 0.303828    [  672/ 1020]
#
#  Avg train loss: 0.350052
# Test accuarcy = 98.6%
# Accuracy on validation set = 42.2%
# Average loss on validation set = 2.6418200954794884
# Epoch 77
# loss: 0.291783    [   32/ 1020]
# loss: 0.332821    [  672/ 1020]
#
#  Avg train loss: 0.317099
# Test accuarcy = 99.4%
# Accuracy on validation set = 43.2%
# Average loss on validation set = 2.6031752452254295
# Epoch 78
# loss: 0.227374    [   32/ 1020]
# loss: 0.364045    [  672/ 1020]
#
#  Avg train loss: 0.285990
# Test accuarcy = 99.5%
# Accuracy on validation set = 42.0%
# Average loss on validation set = 2.6522868424654007
# Epoch 79
# loss: 0.192160    [   32/ 1020]
# loss: 0.266376    [  672/ 1020]
#
#  Avg train loss: 0.264159
# Test accuarcy = 100.0%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.6477013006806374
# Epoch 80
# loss: 0.281092    [   32/ 1020]
# loss: 0.219899    [  672/ 1020]
#
#  Avg train loss: 0.256126
# Test accuarcy = 99.8%
# Accuracy on validation set = 42.5%
# Average loss on validation set = 2.65816480666399
# Epoch 81
# loss: 0.209168    [   32/ 1020]
# loss: 0.308652    [  672/ 1020]
#
#  Avg train loss: 0.256267
# Test accuarcy = 99.7%
# Accuracy on validation set = 42.1%
# Average loss on validation set = 2.6015771999955177
# Epoch 82
# loss: 0.240491    [   32/ 1020]
# loss: 0.244345    [  672/ 1020]
#
#  Avg train loss: 0.257367
# Test accuarcy = 99.5%
# Accuracy on validation set = 41.6%
# Average loss on validation set = 2.6168397329747677
# Epoch 83
# loss: 0.160307    [   32/ 1020]
# loss: 0.322682    [  672/ 1020]
#
#  Avg train loss: 0.231449
# Test accuarcy = 99.8%
# Accuracy on validation set = 40.5%
# Average loss on validation set = 2.6268441155552864
# Epoch 84
# loss: 0.172392    [   32/ 1020]
# loss: 0.204000    [  672/ 1020]
#
#  Avg train loss: 0.204511
# Test accuarcy = 99.8%
# Accuracy on validation set = 41.8%
# Average loss on validation set = 2.6617728769779205
# Epoch 85
# loss: 0.232368    [   32/ 1020]
# loss: 0.313508    [  672/ 1020]
#
#  Avg train loss: 0.213391
# Test accuarcy = 99.6%
# Accuracy on validation set = 43.8%
# Average loss on validation set = 2.5922117605805397
# Epoch 86
# loss: 0.220022    [   32/ 1020]
# loss: 0.155073    [  672/ 1020]
#
#  Avg train loss: 0.192415
# Test accuarcy = 99.7%
# Accuracy on validation set = 41.6%
# Average loss on validation set = 2.6508652716875076
# Epoch 87
# loss: 0.198404    [   32/ 1020]
# loss: 0.225342    [  672/ 1020]
#
#  Avg train loss: 0.198705
# Test accuarcy = 99.7%
# Accuracy on validation set = 41.0%
# Average loss on validation set = 2.6562817879021168
# Epoch 88
# loss: 0.151557    [   32/ 1020]
# loss: 0.298154    [  672/ 1020]
#
#  Avg train loss: 0.180189
# Test accuarcy = 99.9%
# Accuracy on validation set = 41.5%
# Average loss on validation set = 2.621838703751564
# Epoch 89
# loss: 0.163523    [   32/ 1020]
# loss: 0.217361    [  672/ 1020]
#
#  Avg train loss: 0.168924
# Test accuarcy = 100.0%
# Accuracy on validation set = 42.8%
# Average loss on validation set = 2.593391388654709
# Epoch 90
# loss: 0.180595    [   32/ 1020]
# loss: 0.180373    [  672/ 1020]
#
#  Avg train loss: 0.173191
# Test accuarcy = 99.7%
# Accuracy on validation set = 41.2%
# Average loss on validation set = 2.6347974464297295
# Epoch 91
# loss: 0.119458    [   32/ 1020]
# loss: 0.156041    [  672/ 1020]
#
#  Avg train loss: 0.162605
# Test accuarcy = 100.0%
# Accuracy on validation set = 43.3%
# Average loss on validation set = 2.5878029875457287
# Epoch 92
# loss: 0.139784    [   32/ 1020]
# loss: 0.150714    [  672/ 1020]
#
#  Avg train loss: 0.153624
# Test accuarcy = 99.9%
# Accuracy on validation set = 43.0%
# Average loss on validation set = 2.5866518430411816
# Epoch 93
# loss: 0.144304    [   32/ 1020]
# loss: 0.157087    [  672/ 1020]
#
#  Avg train loss: 0.138772
# Test accuarcy = 99.9%
# Accuracy on validation set = 43.5%
# Average loss on validation set = 2.6008180677890778
# Epoch 94
# loss: 0.148477    [   32/ 1020]
# loss: 0.169977    [  672/ 1020]
#
#  Avg train loss: 0.146119
# Test accuarcy = 99.9%
# Accuracy on validation set = 41.2%
# Average loss on validation set = 2.618881978094578
# Epoch 95
# loss: 0.125304    [   32/ 1020]
# loss: 0.123454    [  672/ 1020]
#
#  Avg train loss: 0.138923
# Test accuarcy = 99.8%
# Accuracy on validation set = 42.5%
# Average loss on validation set = 2.632350891828537
# Epoch 96
# loss: 0.117488    [   32/ 1020]
# loss: 0.109494    [  672/ 1020]
#
#  Avg train loss: 0.131818
# Test accuarcy = 99.9%
# Accuracy on validation set = 44.3%
# Average loss on validation set = 2.527802400290966
# Epoch 97
# loss: 0.198211    [   32/ 1020]
# loss: 0.179559    [  672/ 1020]
#
#  Avg train loss: 0.132794
# Test accuarcy = 99.9%
# Accuracy on validation set = 42.7%
# Average loss on validation set = 2.5871197804808617
# Epoch 98
# loss: 0.162016    [   32/ 1020]
# loss: 0.120672    [  672/ 1020]
#
#  Avg train loss: 0.128690
# Test accuarcy = 99.9%
# Accuracy on validation set = 44.1%
# Average loss on validation set = 2.5970628298819065
# Epoch 99
# loss: 0.128055    [   32/ 1020]
# loss: 0.131655    [  672/ 1020]
#
#  Avg train loss: 0.129111
# Test accuarcy = 99.9%
# Accuracy on validation set = 43.3%
# Average loss on validation set = 2.5861969515681267
