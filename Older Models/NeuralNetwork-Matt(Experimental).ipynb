# %%
#imports
import math
#PyTorch imports
import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

#Import SciPy to load the Flowers-102 dataset from the .mat format
import scipy.io

#Other imports
import numpy as np
import matplotlib.pyplot as plt

#Import time so that we can train the model within the 12 hour time limit
import time

# %%
#Define transforms
trainingTransform = transforms.Compose([
    transforms.Resize(224), #Change this value to edit the image size
    transforms.RandomRotation(90), #Rotates each image by a random angle between 0-90 degrees
    transforms.CenterCrop(224), #Must be the same as resize value. This is used to ensure the image is square
    #Default probability for both flips is p=0.5, can be changed if needed
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(0,1) #zerocenter normalization
])

nonTrainTransform = transforms.Compose([
    #Same as training transform without flipping as required
    #by assessment rules
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(0,1)
])

#Load Flowers-102 dataset and split it into train, validate and test splits
trainingSet = datasets.Flowers102(root="./flowers", split="train", download=True, transform=trainingTransform)
validationSet = datasets.Flowers102(root="./flowers", split="val", download=True, transform=nonTrainTransform)
testingSet = datasets.Flowers102(root="./flowers", split="test", download=True, transform=nonTrainTransform)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to flowers/flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:24<00:00, 14139306.83it/s]
# Extracting flowers/flowers-102/102flowers.tgz to flowers/flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to flowers/flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 710371.33it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to flowers/flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 30138265.89it/s]

# %%
#Checking the splits are the correct length
print(len(trainingSet))
print(len(validationSet))
print(len(testingSet))
# Out:
# 1020
# 1020
# 6149

# %%
#Checking the training transformations are ok
figure = plt.figure(figsize=(10,10))
col, row = 2, 2
for i in range(1, 5): #TODO: Change this to be rows * columns
  randImg = torch.randint(len(trainingSet), size=(1,)).item() #Size defines the shape of the tensor
  img, label = trainingSet[randImg]
  figure.add_subplot(row, col, i)
  plt.title(label)
  plt.axis(False)
  plt.imshow(img.squeeze().permute(1,2,0)) #Permute gets the dimentions in the correct order
plt.show()

# %%
#Checking if collab can connect to a GPU
if torch.cuda.is_available():
  device = torch.device('cuda:0')
else:
  device = torch.device('cpu')

# %%
#The CNN itself
class CNN(nn.Module):
  def __init__(self):
    super().__init__()
    #DEFINING THE LAYERS. THIS IS WHERE WE WILL SPEND MOST OF OUR TIME
    self.netLayers = nn.Sequential(
        # block 1 (<- considering how to talk abt layers in method don't mind me)
        nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.MaxPool2d(2,2),

        #block 2
        nn.ReLU(),
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        
        #block 3
        nn.AvgPool2d(2,2),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(256),

        #nn.LeakyReLU(), #LeakyReLU is used to prevent 'dead ReLU' issues
        
        #block 4
        nn.ReLU(),
        nn.MaxPool2d(2,2),
        nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=(1,1), padding=1),
        
        # block 5
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=(1,1), padding=1),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.MaxPool2d(2,2),
        nn.Flatten(),
        #IMPORTANT: in channels for first linear must be
        # (image size) * (image size) * C
        #Where C is the out channels of the last conv2d
        #If confused, just print out the shape of the matrix

        # fully connected layer
        nn.Linear(100352, 1020),
        nn.BatchNorm1d(1020),
        nn.ReLU(),
        nn.Dropout(0.5),

        nn.Linear(1020, 1020),
        nn.BatchNorm1d(1020),
        nn.LeakyReLU(),
        nn.Dropout(0.5),

        nn.Linear(1020, 256),
        nn.BatchNorm1d(256),
        nn.ReLU(),
        nn.Dropout(0.2),

        nn.Linear(256, 102), #102 for the classifiers
        #nn.LogSoftmax(dim=1)
    )
  
  def forward(self, x):
      result = self.netLayers(x)
      #print(result.shape)
      return result
  

print(CNN())
# Out:
# CNN(
#   (netLayers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU()
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Flatten(start_dim=1, end_dim=-1)
#     (24): Linear(in_features=100352, out_features=1020, bias=True)
#     (25): BatchNorm1d(1020, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#     (27): Dropout(p=0.5, inplace=False)
#     (28): Linear(in_features=1020, out_features=1020, bias=True)
#     (29): BatchNorm1d(1020, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (30): LeakyReLU(negative_slope=0.01)
#     (31): Dropout(p=0.5, inplace=False)
#     (32): Linear(in_features=1020, out_features=256, bias=True)
#     (33): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (34): ReLU()
#     (35): Dropout(p=0.2, inplace=False)
#     (36): Linear(in_features=256, out_features=102, bias=True)
#   )
# )

# %%
#TODO: Code to train the CNN on the training set for a set amount of minutes.
def timedTrain(minutes, cnn, lossFunction, optimiser, showGraph):
  startTime = time.time()
  endTime = time.time() + (minutes * 60)
  trainingError = []

# %%
#Code to train the CNN based on a set number of epochs
def epochCountTrain(trainLoader, cnn, optimizer, lossFunction):
  totalLoss, correct = 0, 0
  size = len(trainLoader.dataset)
  for i, data in enumerate(trainLoader, 0):
    input, labels = data
    input = input.to(device)
    labels = labels.to(device)
    optimizer.zero_grad()
    output = cnn(input)
    loss = lossFunction(output, labels)
    loss.backward()
    optimizer.step()
    totalLoss += loss.item()
    correct += (output.argmax(1)==labels).sum().item()
    if i % 20 == 0:
      loss, currentLoss = loss.item(), (i + 1) * len(input)
      print(f"loss: {loss:>7f}    [{currentLoss:>5d}/{size:>5d}]")
      
  epochTrainLoss.append(float(loss))
  epochTrainAccuracy.append(round((correct/1020)*100, 1))
  print(f"\nAvg train loss: {(totalLoss/len(trainLoader)):>8f}")
  print(f"Train accuracy = {((correct/1020) * 100): >0.1f}%")

# %%
#Code to guess accuracy based on validation set
def validation(valLoader, cnn, lossFunction):
  valSize = len(valLoader.dataset)
  correct = 0
  loss = []
  with torch.no_grad(): #as we are not calling backward, use no grad to save memory
    for batch in valLoader:
      input, labels = batch
      input = input.to(device)
      labels = labels.to(device)
      prediciton = cnn(input)
      loss.append(lossFunction(prediciton, labels).item())
      correct += (prediciton.argmax(1) == labels).sum().item()
  
  epochValLoss.append((np.average(loss)))
  epochValAccuracy.append(round((correct/valSize)*100, 1))
  print(f"Accuracy on validation set = {((correct / valSize) * 100):>0.1f}%")
  print(f"Average loss on validation set = {(np.average(loss))}\n")

# %%
#Code that gets the accuracy of the test set!
def test(testLoader, cnn):
  testSize = len(testLoader.dataset)
  correct = 0
  with torch.no_grad():
    for batch in testLoader:
      input, labels = batch
      input = input.to(device)
      labels = labels.to(device)
      prediciton = cnn(input)
      correct +=(prediciton.argmax(1) == labels).sum().item()
  print("----------------------------------------------------")    
  print(f"Accuracy on test set = {((correct / testSize) * 100):>0.1f}%")
  print("----------------------------------------------------")

# %%
#Instantiate the model, loss function and optimiser, done to prevent resets when rerunning the code below
epochCount = 100
learningRate = 1e-4
batchSize = 32
lossFunction = nn.CrossEntropyLoss()
model = CNN().to(device)
optimizer = AdamW(lr=learningRate, params=model.parameters(), weight_decay=1e-5)
scheduler = StepLR(optimizer, step_size=40, gamma=0.1)
trainDataloader = DataLoader(trainingSet, batch_size=batchSize, shuffle=True)
valDataloader = DataLoader(validationSet, batch_size=batchSize, shuffle=True)
testDataloader = DataLoader(validationSet, batch_size=batchSize, shuffle=True)

epochTrainLoss = []
epochTrainAccuracy = []

epochValLoss = []
epochValAccuracy = []

epochCountList = []

# %%
#Actual code to get it all running
for i in range(epochCount):
  print(f"Epoch {i+1}")
  model.train()
  epochCountTrain(trainDataloader, model, optimizer, lossFunction)
  scheduler.step()
  model.eval()
  validation(valDataloader, model, lossFunction)
  epochCountList.append(i+1)
# Out:
# Epoch 1
# loss: 4.591066    [   32/ 1020]
# loss: 4.653932    [  672/ 1020]
#
# Avg train loss: 4.681044
# Train accuracy = 0.9%
# Accuracy on validation set = 1.0%
# Average loss on validation set = 4.6491125375032425
#
# Epoch 2
# loss: 4.607618    [   32/ 1020]
# loss: 4.374249    [  672/ 1020]
#
# Avg train loss: 4.518584
# Train accuracy = 2.4%
# Accuracy on validation set = 4.3%
# Average loss on validation set = 4.452488660812378
#
# Epoch 3
# loss: 4.472143    [   32/ 1020]
# loss: 4.446765    [  672/ 1020]
#
# Avg train loss: 4.439750
# Train accuracy = 3.2%
# Accuracy on validation set = 8.9%
# Average loss on validation set = 4.3005600571632385
#
# Epoch 4
# loss: 4.316420    [   32/ 1020]
# loss: 4.324832    [  672/ 1020]
#
# Avg train loss: 4.319744
# Train accuracy = 5.7%
# Accuracy on validation set = 9.0%
# Average loss on validation set = 4.257521942257881
#
# Epoch 5
# loss: 4.434093    [   32/ 1020]
# loss: 4.157343    [  672/ 1020]
#
# Avg train loss: 4.220772
# Train accuracy = 7.8%
# Accuracy on validation set = 14.2%
# Average loss on validation set = 4.138393722474575
#
# Epoch 6
# loss: 4.102006    [   32/ 1020]
# loss: 4.072762    [  672/ 1020]
#
# Avg train loss: 4.114153
# Train accuracy = 9.2%
# Accuracy on validation set = 11.2%
# Average loss on validation set = 4.110526196658611
#
# Epoch 7
# loss: 3.959196    [   32/ 1020]
# loss: 4.065146    [  672/ 1020]
#
# Avg train loss: 4.073781
# Train accuracy = 10.2%
# Accuracy on validation set = 14.2%
# Average loss on validation set = 3.963267669081688
#
# Epoch 8
# loss: 4.045721    [   32/ 1020]
# loss: 3.802836    [  672/ 1020]
#
# Avg train loss: 3.969806
# Train accuracy = 11.8%
# Accuracy on validation set = 15.7%
# Average loss on validation set = 3.9613958224654198
#
# Epoch 9
# loss: 3.888943    [   32/ 1020]
# loss: 3.929799    [  672/ 1020]
#
# Avg train loss: 3.928899
# Train accuracy = 13.4%
# Accuracy on validation set = 15.4%
# Average loss on validation set = 3.8729014471173286
#
# Epoch 10
# loss: 3.700955    [   32/ 1020]
# loss: 4.063058    [  672/ 1020]
#
# Avg train loss: 3.832826
# Train accuracy = 15.6%
# Accuracy on validation set = 14.8%
# Average loss on validation set = 3.906746208667755
#
# Epoch 11
# loss: 3.801271    [   32/ 1020]
# loss: 3.896870    [  672/ 1020]
#
# Avg train loss: 3.790333
# Train accuracy = 15.0%
# Accuracy on validation set = 16.9%
# Average loss on validation set = 3.778595544397831
#
# Epoch 12
# loss: 3.675254    [   32/ 1020]
# loss: 3.616182    [  672/ 1020]
#
# Avg train loss: 3.727862
# Train accuracy = 17.5%
# Accuracy on validation set = 18.4%
# Average loss on validation set = 3.711343728005886
#
# Epoch 13
# loss: 3.756061    [   32/ 1020]
# loss: 3.808572    [  672/ 1020]
#
# Avg train loss: 3.678037
# Train accuracy = 16.9%
# Accuracy on validation set = 19.5%
# Average loss on validation set = 3.670692153275013
#
# Epoch 14
# loss: 3.776861    [   32/ 1020]
# loss: 3.615830    [  672/ 1020]
#
# Avg train loss: 3.632804
# Train accuracy = 18.9%
# Accuracy on validation set = 21.5%
# Average loss on validation set = 3.671254813671112
#
# Epoch 15
# loss: 3.605566    [   32/ 1020]
# loss: 3.504877    [  672/ 1020]
#
# Avg train loss: 3.557182
# Train accuracy = 21.4%
# Accuracy on validation set = 16.0%
# Average loss on validation set = 3.6655815839767456
#
# Epoch 16
# loss: 3.319334    [   32/ 1020]
# loss: 3.410281    [  672/ 1020]
#
# Avg train loss: 3.516192
# Train accuracy = 21.1%
# Accuracy on validation set = 18.0%
# Average loss on validation set = 3.587797738611698
#
# Epoch 17
# loss: 3.392554    [   32/ 1020]
# loss: 3.334010    [  672/ 1020]
#
# Avg train loss: 3.458814
# Train accuracy = 22.7%
# Accuracy on validation set = 19.6%
# Average loss on validation set = 3.5714388266205788
#
# Epoch 18
# loss: 3.371347    [   32/ 1020]
# loss: 3.400097    [  672/ 1020]
#
# Avg train loss: 3.392233
# Train accuracy = 25.3%
# Accuracy on validation set = 20.1%
# Average loss on validation set = 3.510698899626732
#
# Epoch 19
# loss: 3.459811    [   32/ 1020]
# loss: 3.267265    [  672/ 1020]
#
# Avg train loss: 3.334075
# Train accuracy = 26.5%
# Accuracy on validation set = 24.4%
# Average loss on validation set = 3.4041359797120094
#
# Epoch 20
# loss: 3.262320    [   32/ 1020]
# loss: 3.210309    [  672/ 1020]
#
# Avg train loss: 3.290512
# Train accuracy = 25.9%
# Accuracy on validation set = 22.6%
# Average loss on validation set = 3.4111311733722687
#
# Epoch 21
# loss: 3.337881    [   32/ 1020]
# loss: 3.022856    [  672/ 1020]
#
# Avg train loss: 3.279056
# Train accuracy = 27.7%
# Accuracy on validation set = 23.6%
# Average loss on validation set = 3.3598976507782936
#
# Epoch 22
# loss: 3.212975    [   32/ 1020]
# loss: 3.140222    [  672/ 1020]
#
# Avg train loss: 3.216939
# Train accuracy = 28.4%
# Accuracy on validation set = 23.1%
# Average loss on validation set = 3.3888811841607094
#
# Epoch 23
# loss: 3.219298    [   32/ 1020]
# loss: 3.098920    [  672/ 1020]
#
# Avg train loss: 3.148107
# Train accuracy = 32.6%
# Accuracy on validation set = 28.9%
# Average loss on validation set = 3.2725526988506317
#
# Epoch 24
# loss: 3.081441    [   32/ 1020]
# loss: 3.006220    [  672/ 1020]
#
# Avg train loss: 3.079685
# Train accuracy = 31.6%
# Accuracy on validation set = 27.5%
# Average loss on validation set = 3.2899028584361076
#
# Epoch 25
# loss: 3.118690    [   32/ 1020]
# loss: 3.109726    [  672/ 1020]
#
# Avg train loss: 3.061848
# Train accuracy = 33.0%
# Accuracy on validation set = 26.4%
# Average loss on validation set = 3.24088391661644
#
# Epoch 26
# loss: 2.984990    [   32/ 1020]
# loss: 2.916725    [  672/ 1020]
#
# Avg train loss: 3.002328
# Train accuracy = 33.4%
# Accuracy on validation set = 27.5%
# Average loss on validation set = 3.228759042918682
#
# Epoch 27
# loss: 3.028734    [   32/ 1020]
# loss: 2.809887    [  672/ 1020]
#
# Avg train loss: 2.926241
# Train accuracy = 36.5%
# Accuracy on validation set = 29.6%
# Average loss on validation set = 3.1305187046527863
#
# Epoch 28
# loss: 2.983664    [   32/ 1020]
# loss: 2.909084    [  672/ 1020]
#
# Avg train loss: 2.919665
# Train accuracy = 36.4%
# Accuracy on validation set = 27.3%
# Average loss on validation set = 3.107723981142044
#
# Epoch 29
# loss: 2.656626    [   32/ 1020]
# loss: 2.898464    [  672/ 1020]
#
# Avg train loss: 2.841648
# Train accuracy = 39.7%
# Accuracy on validation set = 29.6%
# Average loss on validation set = 3.087088607251644
#
# Epoch 30
# loss: 2.943784    [   32/ 1020]
# loss: 2.715359    [  672/ 1020]
#
# Avg train loss: 2.857071
# Train accuracy = 38.4%
# Accuracy on validation set = 30.0%
# Average loss on validation set = 3.0579033121466637
#
# Epoch 31
# loss: 2.611789    [   32/ 1020]
# loss: 3.096577    [  672/ 1020]
#
# Avg train loss: 2.775329
# Train accuracy = 40.0%
# Accuracy on validation set = 31.2%
# Average loss on validation set = 3.018351398408413
#
# Epoch 32
# loss: 2.468455    [   32/ 1020]
# loss: 2.665929    [  672/ 1020]
#
# Avg train loss: 2.711756
# Train accuracy = 41.9%
# Accuracy on validation set = 33.6%
# Average loss on validation set = 2.9835048988461494
#
# Epoch 33
# loss: 2.546519    [   32/ 1020]
# loss: 2.961435    [  672/ 1020]
#
# Avg train loss: 2.685819
# Train accuracy = 42.9%
# Accuracy on validation set = 32.0%
# Average loss on validation set = 2.9683706387877464
#
# Epoch 34
# loss: 2.408427    [   32/ 1020]
# loss: 2.446737    [  672/ 1020]
#
# Avg train loss: 2.627624
# Train accuracy = 43.8%
# Accuracy on validation set = 32.4%
# Average loss on validation set = 2.9584567919373512
#
# Epoch 35
# loss: 2.831334    [   32/ 1020]
# loss: 2.759577    [  672/ 1020]
#
# Avg train loss: 2.587190
# Train accuracy = 45.2%
# Accuracy on validation set = 33.8%
# Average loss on validation set = 2.9142191782593727
#
# Epoch 36
# loss: 2.814105    [   32/ 1020]
# loss: 2.193355    [  672/ 1020]
#
# Avg train loss: 2.562734
# Train accuracy = 46.8%
# Accuracy on validation set = 31.4%
# Average loss on validation set = 2.9749249145388603
#
# Epoch 37
# loss: 2.457044    [   32/ 1020]
# loss: 2.586931    [  672/ 1020]
#
# Avg train loss: 2.500256
# Train accuracy = 47.5%
# Accuracy on validation set = 35.2%
# Average loss on validation set = 2.848162703216076
#
# Epoch 38
# loss: 2.719151    [   32/ 1020]
# loss: 2.346765    [  672/ 1020]
#
# Avg train loss: 2.421623
# Train accuracy = 48.2%
# Accuracy on validation set = 33.9%
# Average loss on validation set = 2.8803587183356285
#
# Epoch 39
# loss: 2.392480    [   32/ 1020]
# loss: 2.653341    [  672/ 1020]
#
# Avg train loss: 2.456436
# Train accuracy = 48.9%
# Accuracy on validation set = 36.0%
# Average loss on validation set = 2.8355804160237312
#
# Epoch 40
# loss: 2.070572    [   32/ 1020]
# loss: 2.302353    [  672/ 1020]
#
# Avg train loss: 2.357972
# Train accuracy = 50.1%
# Accuracy on validation set = 36.6%
# Average loss on validation set = 2.790671706199646
#
# Epoch 41
# loss: 2.104212    [   32/ 1020]
# loss: 2.131057    [  672/ 1020]
#
# Avg train loss: 2.279873
# Train accuracy = 54.0%
# Accuracy on validation set = 39.2%
# Average loss on validation set = 2.686075285077095
#
# Epoch 42
# loss: 2.184994    [   32/ 1020]
# loss: 2.071874    [  672/ 1020]
#
# Avg train loss: 2.231169
# Train accuracy = 55.7%
# Accuracy on validation set = 39.1%
# Average loss on validation set = 2.7026515677571297
#
# Epoch 43
# loss: 2.126678    [   32/ 1020]
# loss: 2.277161    [  672/ 1020]
#
# Avg train loss: 2.208230
# Train accuracy = 57.3%
# Accuracy on validation set = 38.7%
# Average loss on validation set = 2.6810445822775364
#
# Epoch 44
# loss: 2.024040    [   32/ 1020]
# loss: 2.521275    [  672/ 1020]
#
# Avg train loss: 2.223181
# Train accuracy = 56.5%
# Accuracy on validation set = 40.2%
# Average loss on validation set = 2.6619949713349342
#
# Epoch 45
# loss: 2.572334    [   32/ 1020]
# loss: 1.972243    [  672/ 1020]
#
# Avg train loss: 2.172669
# Train accuracy = 58.2%
# Accuracy on validation set = 40.1%
# Average loss on validation set = 2.663455054163933
#
# Epoch 46
# loss: 1.969396    [   32/ 1020]
# loss: 1.777811    [  672/ 1020]
#
# Avg train loss: 2.174700
# Train accuracy = 58.2%
# Accuracy on validation set = 40.1%
# Average loss on validation set = 2.6658913791179657
#
# Epoch 47
# loss: 1.793272    [   32/ 1020]
# loss: 2.350564    [  672/ 1020]
#
# Avg train loss: 2.152414
# Train accuracy = 57.7%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.6470176726579666
#
# Epoch 48
# loss: 2.130804    [   32/ 1020]
# loss: 2.190150    [  672/ 1020]
#
# Avg train loss: 2.167029
# Train accuracy = 58.4%
# Accuracy on validation set = 40.5%
# Average loss on validation set = 2.6610517874360085
#
# Epoch 49
# loss: 2.069469    [   32/ 1020]
# loss: 2.516742    [  672/ 1020]
#
# Avg train loss: 2.172814
# Train accuracy = 56.9%
# Accuracy on validation set = 40.6%
# Average loss on validation set = 2.6418077796697617
#
# Epoch 50
# loss: 2.154506    [   32/ 1020]
# loss: 2.329420    [  672/ 1020]
#
# Avg train loss: 2.141324
# Train accuracy = 58.8%
# Accuracy on validation set = 41.0%
# Average loss on validation set = 2.6606803238391876
#
# Epoch 51
# loss: 2.151974    [   32/ 1020]
# loss: 1.970268    [  672/ 1020]
#
# Avg train loss: 2.132882
# Train accuracy = 58.5%
# Accuracy on validation set = 41.3%
# Average loss on validation set = 2.6451455801725388
#
# Epoch 52
# loss: 2.137092    [   32/ 1020]
# loss: 2.134995    [  672/ 1020]
#
# Avg train loss: 2.124921
# Train accuracy = 59.0%
# Accuracy on validation set = 40.8%
# Average loss on validation set = 2.65040086209774
#
# Epoch 53
# loss: 2.064072    [   32/ 1020]
# loss: 2.023761    [  672/ 1020]
#
# Avg train loss: 2.091797
# Train accuracy = 61.1%
# Accuracy on validation set = 40.3%
# Average loss on validation set = 2.621004670858383
#
# Epoch 54
# loss: 2.092681    [   32/ 1020]
# loss: 2.198059    [  672/ 1020]
#
# Avg train loss: 2.117467
# Train accuracy = 57.9%
# Accuracy on validation set = 41.6%
# Average loss on validation set = 2.647565573453903
#
# Epoch 55
# loss: 2.146803    [   32/ 1020]
# loss: 1.748827    [  672/ 1020]
#
# Avg train loss: 2.086735
# Train accuracy = 61.5%
# Accuracy on validation set = 40.3%
# Average loss on validation set = 2.6356488540768623
#
# Epoch 56
# loss: 2.190973    [   32/ 1020]
# loss: 2.119290    [  672/ 1020]
#
# Avg train loss: 2.099508
# Train accuracy = 60.1%
# Accuracy on validation set = 41.0%
# Average loss on validation set = 2.621008962392807
#
# Epoch 57
# loss: 2.022588    [   32/ 1020]
# loss: 2.296895    [  672/ 1020]
#
# Avg train loss: 2.087382
# Train accuracy = 59.4%
# Accuracy on validation set = 41.1%
# Average loss on validation set = 2.613212175667286
#
# Epoch 58
# loss: 2.004964    [   32/ 1020]
# loss: 1.942984    [  672/ 1020]
#
# Avg train loss: 2.076983
# Train accuracy = 59.6%
# Accuracy on validation set = 40.8%
# Average loss on validation set = 2.60310460627079
#
# Epoch 59
# loss: 1.910070    [   32/ 1020]
# loss: 2.250774    [  672/ 1020]
#
# Avg train loss: 2.063895
# Train accuracy = 61.4%
# Accuracy on validation set = 42.0%
# Average loss on validation set = 2.6004016175866127
#
# Epoch 60
# loss: 1.994933    [   32/ 1020]
# loss: 2.282904    [  672/ 1020]
#
# Avg train loss: 2.044806
# Train accuracy = 60.8%
# Accuracy on validation set = 42.4%
# Average loss on validation set = 2.605123206973076
#
# Epoch 61
# loss: 1.960413    [   32/ 1020]
# loss: 2.299808    [  672/ 1020]
#
# Avg train loss: 2.042588
# Train accuracy = 62.4%
# Accuracy on validation set = 41.2%
# Average loss on validation set = 2.6299824193120003
#
# Epoch 62
# loss: 1.887109    [   32/ 1020]
# loss: 2.026689    [  672/ 1020]
#
# Avg train loss: 2.035441
# Train accuracy = 62.4%
# Accuracy on validation set = 41.4%
# Average loss on validation set = 2.6111200377345085
#
# Epoch 63
# loss: 2.304182    [   32/ 1020]
# loss: 1.946665    [  672/ 1020]
#
# Avg train loss: 2.036207
# Train accuracy = 63.3%
# Accuracy on validation set = 42.5%
# Average loss on validation set = 2.5941998437047005
#
# Epoch 64
# loss: 1.846623    [   32/ 1020]
# loss: 2.041993    [  672/ 1020]
#
# Avg train loss: 1.995988
# Train accuracy = 63.1%
# Accuracy on validation set = 42.0%
# Average loss on validation set = 2.5943609699606895
#
# Epoch 65
# loss: 2.007823    [   32/ 1020]
# loss: 2.033139    [  672/ 1020]
#
# Avg train loss: 2.001318
# Train accuracy = 63.9%
# Accuracy on validation set = 42.5%
# Average loss on validation set = 2.5815294459462166
#
# Epoch 66
# loss: 2.034052    [   32/ 1020]
# loss: 1.997704    [  672/ 1020]
#
# Avg train loss: 2.011274
# Train accuracy = 61.7%
# Accuracy on validation set = 41.8%
# Average loss on validation set = 2.579093284904957
#
# Epoch 67
# loss: 1.822638    [   32/ 1020]
# loss: 2.123329    [  672/ 1020]
#
# Avg train loss: 1.995003
# Train accuracy = 62.8%
# Accuracy on validation set = 42.4%
# Average loss on validation set = 2.587055779993534
#
# Epoch 68
# loss: 2.001460    [   32/ 1020]
# loss: 2.289258    [  672/ 1020]
#
# Avg train loss: 1.996824
# Train accuracy = 61.9%
# Accuracy on validation set = 42.1%
# Average loss on validation set = 2.6057312414050102
#
# Epoch 69
# loss: 2.101256    [   32/ 1020]
# loss: 1.680175    [  672/ 1020]
#
# Avg train loss: 1.990270
# Train accuracy = 64.9%

# %%
#plot the loss and accuracy of the training and validation set
plt.plot(epochCountList, epochTrainLoss, label="Training loss")
plt.plot(epochCountList, epochValLoss, label="Validation loss")
plt.title("Train & validation loss")
plt.legend()
plt.show()

plt.plot(epochCountList, epochTrainAccuracy, label="Training accuracy")
plt.plot(epochCountList, epochValAccuracy, label="Validation accuracy")
plt.title("Train & validation accuracy")
plt.legend()
plt.show()

# %%
#Save the model to the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
PATH ="./47PercentTestAcc.pth"
torch.save(model.state_dict(), PATH)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-3c4594da656e> in <cell line: 2>()
#       1 PATH ="MyDrive/47PercentTestAcc.pth"
# ----> 2 torch.save(model.state_dict(), PATH)
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     438
#     439     if _use_new_zipfile_serialization:
# --> 440         with _open_zipfile_writer(f) as opened_zipfile:
#     441             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442             return
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_zipfile_writer(name_or_buffer)
#     313     else:
#     314         container = _open_zipfile_writer_buffer
# --> 315     return container(name_or_buffer)
#     316
#     317
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name)
#     286 class _open_zipfile_writer_file(_opener):
#     287     def __init__(self, name) -> None:
# --> 288         super().__init__(torch._C.PyTorchFileWriter(str(name)))
#     289
#     290     def __exit__(self, *args) -> None:
#
# RuntimeError: Parent directory MyDrive does not exist.

# %%
#Run the model on the test set
test(testDataloader, model)
# Out:
# ----------------------------------------------------
# Accuracy on test set = 47.2%
# ----------------------------------------------------
